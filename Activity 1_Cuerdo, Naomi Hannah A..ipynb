# %%
#calculate average function
def average(score):
    return sum(score)/len(score)

#list for storing the quiz scores
def records():
    five_quiz = []
    two_assignments = []
    two_seatwork = []

    for x in range(5):
        quiz_score = float(input("Enter score in quizzes: "))
        five_quiz.append(quiz_score)

    for y in range(2):
        assignment_score = float(input("Enter score in assignment: "))
        two_assignments.append(assignment_score)

    for z in range(2):
        seatwork_score = float(input("Enter score in seatwork: "))
        two_seatwork.append(seatwork_score)

    one_major_exam = float(input("Enter score in major exam: "))

    #AQ
    average_quizzes = average(five_quiz)

    #CS
    count_scores = average(two_assignments + two_seatwork)

    #grade 
    grade = 0.5*one_major_exam + 0.4*average_quizzes + 0.1*count_scores

    print("Final Grade: ", grade)

#calling out record function
records()
# Out:
# Enter score in quizzes: 12
# Enter score in quizzes: 12
# Enter score in quizzes: 34
# Enter score in quizzes: 23
# Enter score in quizzes: 20
# Enter score in assignments: 50
# Enter score in assignments: 48
# Enter score in seatworks: 90
# Enter score in seatworks: 42
# Enter score in major exam: 100
# Final Grade:  63.83

# %%
#FINAL CODE 

def calc_average(score):
    return sum(score) / len(score)

#lists to store the scores
def grades():
    quizzes = []
    assignments = []
    seatworks = []
    
    # 5 quizzes
    score_one = float(input("Enter score in quiz 1: "))
    quizzes.append(score_one)
    
    score_two = float(input("Enter score in quiz 2: "))
    quizzes.append(score_two)
    
    score_three = float(input("Enter score in quiz 3: "))
    quizzes.append(score_three)
    
    score_four = float(input("Enter score in quiz 4: "))
    quizzes.append(score_four)
    
    score_five = float(input("Enter score in quiz 5: "))
    quizzes.append(score_five)
    
    # 2 assignments
    assignment_one = float(input("Enter score in assignment 1: "))
    assignments.append(assignment_one)
    
    assignment_two = float(input("Enter score in assignment 2: "))
    assignments.append(assignment_two)
    
    # 2 seat works 
    sw_one = float(input("Enter score in seatwork 1: "))
    seatworks.append(sw_one)
        
    sw_two = float(input("Enter score in seatwork 2: "))
    seatworks.append(sw_two)
    
    # major exam 
    major_exam =  float(input("Enter score in major exam: "))
    
    #AQ
    average_quiz = calc_average(quizzes)
    
    #cs
    count_scores = calc_average(assignments + seatworks)
    
    
    final_grade = 0.5*major_exam + 0.4*average_quiz + 0.1*count_scores

    print("Final Grade: ", final_grade)
    

grades()
# Out:
# Enter score in quiz 1: 12
# Enter score in quiz 2: 12
# Enter score in quiz 3: 34
# Enter score in quiz 4: 23
# Enter score in quiz 5: 20
# Enter score in assignment 1: 50
# Enter score in assignment 2: 48
# Enter score in seatwork 1: 90
# Enter score in seatwork 2: 42
# Enter score in major exam: 100
# Final Grade:  63.83

# %%
def calc_average(score,total_score):
    return sum(score) / sum(total_score)

#lists to store the recorded scores
def grades():
    quizzes = []
    assignments = []
    seatworks = []

#lists to store the total scores
    total_quizzes = []
    total_assignments = []
    total_seatworks = []
    
# number of quiz, assignments, sw
    num_quiz = 5
    num_assignments = 2
    num_sw = 2
    
# input scores and total score for quizzes, assign, sw
    for x in range(num_quiz):
        score =  float(input(f"Enter score in quiz {x+1}: "))
        total_score = float(input(f"Enter total score in quiz {x+1}: "))
        quizzes.append(score)
        total_quizzes.append(total_score)
    
    for x in range(num_assignments):
        score =  float(input(f"Enter score in assignment {x+1}: "))
        total_score = float(input(f"Enter total score in assignment {x+1}: "))
        assignments.append(score)
        total_assignments.append(total_score)
        
    for x in range(num_sw):
        score =  float(input(f"Enter score in seatwork {x+1}: "))
        total_score = float(input(f"Enter total score in seatwork {x+1}: "))
        seatworks.append(score)
        total_seatworks.append(total_score)
        
    major_exam =  float(input("Enter score in major exam: "))
    total_major_exam = float(input("Enter total score in major exam: "))
    
    
#AQ
    average_quiz = calc_average(quizzes, total_quizzes)
#CS
    count_scores = calc_average(assignments + seatworks, total_assignments + total_seatworks)
    
#Final grade
    final_grade = 0.5*(major_exam /total_major_exam) + 0.4*average_quiz + 0.1*count_scores
    
    print("Final grade: ", final_grade)
    
grades()
# Out:
# Enter score in quiz 1: 12
# Enter total score in quiz 1: 15
# Enter score in quiz 2: 13
# Enter total score in quiz 2: 15
# Enter score in quiz 3: 10
# Enter total score in quiz 3: 15
# Enter score in quiz 4: 8
# Enter total score in quiz 4: 15
# Enter score in quiz 5: 12
# Enter total score in quiz 5: 15
# Enter score in assignment 1: 5
# Enter total score in assignment 1: 5
# Enter score in assignment 2: 3
# Enter total score in assignment 2: 5
# Enter score in seatwork 1: 2
# Enter total score in seatwork 1: 5
# Enter score in seatwork 2: 1
# Enter total score in seatwork 2: 4
# Enter score in major exam: 80
# Enter total score in major exam: 100
# Final grade:  0.7512280701754386
